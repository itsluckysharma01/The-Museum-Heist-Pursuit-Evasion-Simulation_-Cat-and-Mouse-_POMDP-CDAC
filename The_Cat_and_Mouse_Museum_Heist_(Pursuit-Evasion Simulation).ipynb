# %% [markdown]
# # Project Title: The "Cat and Mouse" Museum Heist (Pursuit-Evasion Simulation)

# %% [markdown]
# ### ***Create a grid-world museum simulation where a Security Guard AI tries to catch an Intruder AI.***
#
#
# ![`image.png`](attachment:image.png)

# %% [markdown]
# ### install Libraries

# %%
# %pip install numpy pygame gymnasium pomdp-py matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/952.1 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/952.1 kB ? eta -:--:--
#    ---------------------- ----------------- 524.3/952.1 kB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 786.4/952.1 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 952.1/952.1 kB 1.5 MB/s  0:00:00
# ...
# Failed to build pomdp-py
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...
